# %% [markdown]
# # 2.7 OPERADORES LOGICOS

# %%
#los operadores logicos siguen las reglas de la logica proposicional

# %% [markdown]
# ## A) AND

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
False and False
# Out:
# False

# %%
False and True
# Out:
# False

# %% [markdown]
# ## B) OR

# %%
True or False
# Out:
# True

# %%
True or True
# Out:
# True

# %%
False or False
# Out:
# False

# %%
False and True
# Out:
# False

# %%
False or True
# Out:
# True

# %% [markdown]
# ## C) NOT**

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %% [markdown]
# ## Operadores Logicas

# %% [markdown]
# #### [==; !=; <; >; <=; >=]

# %% [markdown]
# #### Para probar igualdad utilizamos usamos el operador ==

# %%
print("¿Se cumple que 2 == 2?\n", 2 == 2)
# Out:
# ¿Se cumple que 2 == 2?
#  True

# %%
print("¿Se cumple que 2 == 2?\n", 2 == 3)
# Out:
# ¿Se cumple que 2 == 2?
#  False

# %% [markdown]
# ### Para probar desigualdad utilizamos usamos el operador !=

# %%
print("¿Se cumple que 2 != 2?\n", 2 != 2)
# Out:
# ¿Se cumple que 2 != 2?
#  False

# %%
print("¿Se cumple que 2 != 2?\n", 2 != 7)
# Out:
# ¿Se cumple que 2 != 2?
#  True

# %% [markdown]
# ### Para comparar magnitudes usamos >,<,>=,<=

# %%
print("¿Se cumple que 2 < 3 \n", 2 < 3)

print("¿Se cumple que 2 > 3 \n", 2<  3)

print("¿Se cumple que 2 =< 3 \n", 2 <= 3)
      
print("¿Se cumple que 2 =< 3?\n", 2 >= 3 )
# Out:
# ¿Se cumple que 2 < 3
#  True
# ¿Se cumple que 2 > 3
#  True
# ¿Se cumple que 2 =< 3
#  True
# ¿Se cumple que 2 =< 3?
#  False

# %%
print("¿Se cumple que 2 < 3 \n", 2 < 3)
# Out:
# ¿Se cumple que 2 < 3
#  True

# %%
print("¿Se cumple que 2 > 3 \n", 2<  3)
# Out:
# ¿Se cumple que 2 > 3
#  True

# %%
print("¿Se cumple que 2 =< 3 \n", 2 <= 3)
# Out:
# ¿Se cumple que 2 =< 3
#  True

# %% [markdown]
# ## Los operadores basicos de asignacion ( <,>,<=,>=,==,!=) tambien aplican a las cadenas de caracteres. Para compararlas Python sigue el estandard ASCII

# %%
print("casa"<"cabra")
# Out:
# False

# %%
##Porque la letra b ocupa el lugar 3 mientras que s como el 18
